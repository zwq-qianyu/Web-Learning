# %% [markdown]
# # 数据清洗

# %% [markdown]
# 1、缺失值处理<br>
# 2、异常值处理<br>
# 3、重复值处理<br>

# %% [markdown]
# 处理方式一般有2种：drop去掉、fill填充、interpolate插值拟合

# %%
import pandas as pd

# %%
data = {
    'name': ['Jack', 'Mary', 'Lily', 'Tom', 'Joe', None],
    'age': [18, None, 21, 25, 24, None],
    'score': ['A', 'B', 'A', None, None, None]
}

df = pd.DataFrame(data, columns = ['name', 'age', 'score'])
df
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary   NaN     B
# 2  Lily  21.0     A
# 3   Tom  25.0  None
# 4   Joe  24.0  None
# 5  None   NaN  None

# %%
df.isnull().sum()
# Out:
# name     1
# age      2
# score    3
# dtype: int64

# %% [markdown]
# ### 1、dropna()

# %%
df.dropna()      # 删除有None的数据
# Out:
#    name   age score
# 0  Jack  18.0     A
# 2  Lily  21.0     A

# %%
df.dropna(how='all')    # 删除一组数据全部（all）是None的数据，how默认是 any
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary   NaN     B
# 2  Lily  21.0     A
# 3   Tom  25.0  None
# 4   Joe  24.0  None

# %%
df
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary   NaN     B
# 2  Lily  21.0     A
# 3   Tom  25.0  None
# 4   Joe  24.0  None
# 5  None   NaN  None

# %%
df.dropna(subset=['age'])    # 删除指定列数据为None的数据
# Out:
#    name   age score
# 0  Jack  18.0     A
# 2  Lily  21.0     A
# 3   Tom  25.0  None
# 4   Joe  24.0  None

# %% [markdown]
# ### 2、fillna(...)

# %%
df.fillna(0)
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary   0.0     B
# 2  Lily  21.0     A
# 3   Tom  25.0     0
# 4   Joe  24.0     0
# 5     0   0.0     0

# %%
df.fillna({'age': 0, 'score': 'D'})
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary   0.0     B
# 2  Lily  21.0     A
# 3   Tom  25.0     D
# 4   Joe  24.0     D
# 5  None   0.0     D

# %%
df.fillna(method='ffill')    # font fill    None的数据按照他的前一个数据填写
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary  18.0     B
# 2  Lily  21.0     A
# 3   Tom  25.0     A
# 4   Joe  24.0     A
# 5   Joe  24.0     A

# %%
df.fillna(method='bfill')   # back fill     score列因为后面没有数据，所以没能填充
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary  21.0     B
# 2  Lily  21.0     A
# 3   Tom  25.0  None
# 4   Joe  24.0  None
# 5  None   NaN  None

# %%
df.fillna({'age': df.age.mean()})     # 用平均数填充
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary  22.0     B
# 2  Lily  21.0     A
# 3   Tom  25.0  None
# 4   Joe  24.0  None
# 5  None  22.0  None

# %%
df.fillna({'age': df.age.median()})     # 用中位数填充
# Out:
#    name   age score
# 0  Jack  18.0     A
# 1  Mary  22.5     B
# 2  Lily  21.0     A
# 3   Tom  25.0  None
# 4   Joe  24.0  None
# 5  None  22.5  None

# %%
df.fillna({'score': 'missing'})
# Out:
#    name   age    score
# 0  Jack  18.0        A
# 1  Mary   NaN        B
# 2  Lily  21.0        A
# 3   Tom  25.0  missing
# 4   Joe  24.0  missing
# 5  None   NaN  missing

# %%
df.fillna({'score': 'missing'}, limit=1)
# Out:
#    name   age    score
# 0  Jack  18.0        A
# 1  Mary   NaN        B
# 2  Lily  21.0        A
# 3   Tom  25.0  missing
# 4   Joe  24.0     None
# 5  None   NaN     None

# %%
df.fillna({'score': 'missing'}, limit=1, inplace=True)   # 加上 inplace=True 可以在运行后保存到原来的数据中
df
# Out:
#    name   age    score
# 0  Jack  18.0        A
# 1  Mary   NaN        B
# 2  Lily  21.0        A
# 3   Tom  25.0  missing
# 4   Joe  24.0     None
# 5  None   NaN     None

# %% [markdown]
# ###  3、interpolate

# %%
df
# Out:
#    name   age    score
# 0  Jack  18.0        A
# 1  Mary   NaN        B
# 2  Lily  21.0        A
# 3   Tom  25.0  missing
# 4   Joe  24.0     None
# 5  None   NaN     None

# %%
df.interpolate()   # 默认线性插值
# Out:
#    name   age    score
# 0  Jack  18.0        A
# 1  Mary  19.5        B
# 2  Lily  21.0        A
# 3   Tom  25.0  missing
# 4   Joe  24.0     None
# 5  None  24.0     None

# %%
# df.interpolate?

# %% [markdown]
# 插值方式：
# method : {'linear', 'time', 'index', 'values', 'nearest', 'zero',
#           'slinear', 'quadratic', 'cubic', 'barycentric', 'krogh',
#           'polynomial', 'spline', 'piecewise_polynomial',
#           'from_derivatives', 'pchip', 'akima'}

# %%
df.interpolate(method='cubic')
# Out:
#    name   age    score
# 0  Jack  18.0        A
# 1  Mary  17.0        B
# 2  Lily  21.0        A
# 3   Tom  25.0  missing
# 4   Joe  24.0     None
# 5  None   NaN     None

# %% [markdown]
# ## 异常值处理

# %%
df.loc[6] = {'name': 'test', 'age': 999, 'score': 'C'}

# %%
df
# Out:
#    name    age    score
# 0  Jack   18.0        A
# 1  Mary    NaN        B
# 2  Lily   21.0        A
# 3   Tom   25.0  missing
# 4   Joe   24.0     None
# 5  None    NaN     None
# 6  test  999.0        C

# %%
q_upper = df['age'].quantile(0.75)
q_upper
# Out:
# 25.0

# %%
q_lower = df['age'].quantile(0.25)
q_lower
# Out:
# 21.0

# %%
val = q_upper - q_lower
val
# Out:
# 4.0

# %%
k = 1.5

# %%
df[df['age'] > q_upper + k * val]
# Out:
#    name    age score
# 6  test  999.0     C

# %%
df2 = df.drop(6)

# %%
df2
# Out:
#    name   age    score
# 0  Jack  18.0        A
# 1  Mary   NaN        B
# 2  Lily  21.0        A
# 3   Tom  25.0  missing
# 4   Joe  24.0     None
# 5  None   NaN     None

# %%
df[(df['age'] < q_upper + k * val) & (df['age'] > q_lower - k * val)]
# Out:
#    name   age    score
# 0  Jack  18.0        A
# 2  Lily  21.0        A
# 3   Tom  25.0  missing
# 4   Joe  24.0     None

# %% [markdown]
# ## 重复值

# %% [markdown]
# ### drop_duplicates()

# %%
df
# Out:
#    name    age    score
# 0  Jack   18.0        A
# 1  Mary    NaN        B
# 2  Lily   21.0        A
# 3   Tom   25.0  missing
# 4   Joe   24.0     None
# 5  None    NaN     None
# 6  test  999.0        C

# %%
df.loc[7] = {'name': 'test', 'age': 999, 'score': 'C'}

# %%
df.loc[8] = {'name': 'test2', 'age': 999, 'score': 'C'}

# %%
df
# Out:
#     name    age    score
# 0   Jack   18.0        A
# 1   Mary    NaN        B
# 2   Lily   21.0        A
# 3    Tom   25.0  missing
# 4    Joe   24.0     None
# 5   None    NaN     None
# 6   test  999.0        C
# 7   test  999.0        C
# 8  test2  999.0        C

# %%
df.drop_duplicates()     # 一行数据与另一行数据完全相同才判定为重复
# Out:
#     name    age    score
# 0   Jack   18.0        A
# 1   Mary    NaN        B
# 2   Lily   21.0        A
# 3    Tom   25.0  missing
# 4    Joe   24.0     None
# 5   None    NaN     None
# 6   test  999.0        C
# 8  test2  999.0        C

# %%
df.drop_duplicates(['age', 'score'])      # 只要age和score两列相同，就判定为重复值
# Out:
#    name    age    score
# 0  Jack   18.0        A
# 1  Mary    NaN        B
# 2  Lily   21.0        A
# 3   Tom   25.0  missing
# 4   Joe   24.0     None
# 5  None    NaN     None
# 6  test  999.0        C
